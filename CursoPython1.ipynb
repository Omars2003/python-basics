# %% [markdown]
# # 🐍 Curso basico PYTHON 🐍
#
# Omar Martínez García

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ventajas:
#
# 🟤  Comunidad activa y soporte, además cuenta con una documentación completa y actualizada, así como con un amplio soporte en línea.
#
# 🟤 Amplia biblioteca estándar.
#
# 🟤Legibilidad y simplicidad.
#
# 🟤Multiparadigma

# %% [markdown]
# # Instalación 🐍

# %% [markdown]
# 1.   Abre  https://www.python.org/.
# 2.   Haz clic en el enlace "Downloads" (Descargas)
# 1.   Verás las versiones más recientes de Python disponibles,de acuerdo a tu OS
# 2.   Haz clic en el enlace de descarga del archivo de instalación que corresponda a tu sistema operativo y arquitectura (32 o 64 bits).
# 1.   Una vez que se complete la descarga, ejecuta el archivo de instalación. Asegúrate de marcar la casilla "Add Python to PATH" (Agregar Python al PATH) durante el proceso de instalación.
# 2.    en cmd escribe python --version. Debería mostrarse la versión de Python instalada.
#
# O puede utlizar google colab

# %% [markdown]
# # Variables y tipos de datos 📑 🐍

# %%
# Ejemplos de números
entero = 10  
flotante = 3.14

print("Ejemplos de números:")
print("Número entero:", entero)
print("Tipo de dato:", type(entero))  # type() devuelve el tipo de dato

print("Número flotante:", flotante)
print("Tipo de dato:", type(flotante))

# Ejemplos de cadenas de texto
mensaje = "IAM3D"
nombre = "OMARS"

print("\nEjemplos de cadenas de texto:")
print("Mensaje:", mensaje)
print("Tipo de dato:", type(mensaje))

print("Nombre:", nombre)
print("Tipo de dato:", type(nombre))

# %%
# Operaciones con números
suma = entero + flotante
resta = entero - flotante
multiplicacion = entero * flotante
division = entero / flotante


print("\nOperaciones con números:")
print("Suma:", suma)
print("Resta:", resta)
print("Multiplicación:", multiplicacion)
print("División:", division)

# Operaciones con cadenas de texto
saludo = mensaje + " Soy " + nombre
repetir = mensaje * 4

print("\nOperaciones con cadenas de texto:")
print("Saludo:", saludo)
print("Repetir:", repetir)

# %%
#Operaciones con entradas del usuario 
#se utiliza la funcion input
x=int(input("x="))
y = float(input("Ingresa un número decimal: "))
sum=x+y
print(sum)

# %% [markdown]
# Ejercicios:
#
# 1.-Realiza una division de numeros floats ingresados por el usuario y una multiplicacion los mismos numeros.

# %%
num1 = ## tu codigo
num2 = # tu codigo 

div=# tu codigo

# %% [markdown]
# ## Solución

# %%
num1=float(input("ingresa el primer numero decimal:"))
num2=float(input("ingresa el segundo numero decimal:"))
div= num1 / num2
print("resultado:",div)
# Out:
# ingresa el primer numero decimal:42.79
# ingresa el primer numero decimal:2.5
# resultado: 17.116

# %% [markdown]
# # Str, cadenas de texto 📚 🔛

# %%
# Solicitar el nombre del usuario
nombre = input("¿Cuál es tu nombre? ")

# Crear un saludo personalizado
saludo = "¡Hola, " + nombre + "! Bienvenido al programa."

# Imprimir el saludo
print(saludo)

# Obtener la longitud del nombre
longitud = len(nombre)

# Imprimir la longitud del nombre
print("Tu nombre tiene", longitud, "caracteres.")

# Convertir el nombre a mayúsculas
nombre_mayusculas = nombre.upper()

# Imprimir el nombre en mayúsculas
print("Tu nombre en mayúsculas es:", nombre_mayusculas)

# %% [markdown]
# Valores booleanos
#
# true or false ,0 1

# %%
#verificar si es impar
numero = int(input("Ingresa un número: "))

es_par = numero % 2 == 0

if es_par:
    print("El número es par.")
else:
    print("El número es impar.")

# %%
puntuacion = int(input("Ingresa la puntuación del examen: "))

aprobado = puntuacion >= 60

if aprobado:
    print("¡Felicidades! Has aprobado el examen.")
else:
    print("Lo siento, has reprobado el examen.")
#el aprobado toma el valor de TRUE y si reprobo toma el valor de FALSE
#

# %% [markdown]
# # Expresiones logicas y control de flujo  🎴

# %% [markdown]
# Las expresiones lógicas son combinaciones de operadores lógicos y operandos que evalúan condiciones y devuelven un valor booleano, es decir, True (verdadero) o False (falso).
#
# Las mas comunes:
#
#  ✍ (y lógico): Devuelve True si ambas condiciones son verdaderas.
#
#  ✍or (o lógico): Devuelve True si al menos una de las condiciones es verdadera.
#
# ✍ not (negación lógica): Invierte el valor de una condición. Si la condición es verdadera, devuelve False; si es falsa, devuelve True.

# %% [markdown]
# Ejemplos ⚓
#
# 💥  5 > 3 and 2 < 1 devuelve False porque la primera condición es verdadera, pero la segunda es falsa.
#
# 💥5 > 3 or 2 < 1 devuelve True porque al menos una de las condiciones es verdadera.
#
# 💥not (4 == 4) devuelve False porque la condición inicial es verdadera, pero la negación invierte su valor.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  👺 Las expresiones lógicas son ampliamente utilizadas en estructuras de control condicionales, como if, elif y while, para tomar decisiones basadas en condiciones y controlar el flujo de ejecución del programa.

# %%
# Solicitar el nombre y la edad del usuario
nombre = input("Ingresa tu nombre: ")
edad = int(input("Ingresa tu edad: "))

# Verificar si el usuario es mayor de edad y tiene permiso de conducir
if edad >= 18:
    tiene_permiso_conducir = input("¿Tienes permiso de conducir? (s/n): ")
    if tiene_permiso_conducir.lower() == "s":
        print("Hola,", nombre, "Eres mayor de edad y tienes permiso de conducir.")
    else:
        print("Hola,", nombre, "Eres mayor de edad, pero no tienes permiso de conducir.")
else:
    print("Hola,", nombre, "Eres menor de edad. No puedes conducir legalmente.")

numero = float(input("Ingresa un número: "))

if numero > 0:
    print("El número", numero, "es positivo.")
elif numero < 0:
    print("El número", numero, "es negativo.")
else:
    print("El número es cero.")

# Verificar si el número es divisible por 3 y 5 simultáneamente
if numero % 3 == 0 and numero % 5 == 0:
    print("El número", numero, "es divisible por 3 y 5 al mismo tiempo.")
else:
    print("El número", numero, "no es divisible por 3 y 5 al mismo tiempo.")

# %% [markdown]
# Ejercicio ⛄
#
# 1.-Realiza un programa que solicite ingresar 2 números al usuario tipo float, y que verifique si son positivos los dos números,si lo son que imprima un mensaje que exprese que ambos son positivos y si no que imprima que al menos uno no es positivo.
#
# 2.-Posterior a eso que verifique si al menos uno es par, si es par que imprima que al menos uno es par y si no que ninguno es par.
#
# 3.-Por ultimo que verifique si los numeros ingresados son iguales,si lo son que imprima si son igual, de lo contrario que imprima que no son iguales.

# %%
# Solicitar dos números al usuario
numero1 = 
numero2 = 

# Verificar si ambos números son positivos y que imprima
son_positivos = 

        # tu codigo


# Verificar si al menos uno de los números es par
es_par =
            ##tu codigo


# Verificar si los dos números son iguales
son_iguales = 


## tu codigo

# %% [markdown]
# ## Solución

# %%
# Solicitar dos números al usuario
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))

# Verificar si ambos números son positivos
son_positivos = numero1 > 0 and numero2 > 0

if son_positivos:
    print("Ambos números son positivos.")
else:
    print("Al menos uno de los números no es positivo.")

# Verificar si al menos uno de los números es par
es_par = numero1 % 2 == 0 or numero2 % 2 == 0

if es_par:
    print("Al menos uno de los números es par.")
else:
    print("Ninguno de los números es par.")

# Verificar si los dos números son iguales
son_iguales = numero1 == numero2

if son_iguales:
    print("Los dos números son iguales.")
else:
    print("Los dos números no son iguales.")
# Out:
# Ingresa el primer número: 7
# Ingresa el segundo número: 8
# Ambos números son positivos.
# Al menos uno de los números es par.
# Los dos números no son iguales.
